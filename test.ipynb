# %%
## Nobite Analytics
#monday 7.09.2026:

# %%
#first step looking at umsatzstatistik jan 2026
import pandas as pd 
import os

# %%
df_sales = pd.read_excel("data/raw/sales_2026/Umsatzstatistik Tropical Concept 31.01.2026.xlsx")

# %%
df_sales.head()
# Out:
#   Versanddatum    Auftragsart         Qualifier Beschreibung  Auftrag  \
# 0   2026-01-02  Normalauftrag  Auftragsposition      Verkauf   615752
# 1   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615885
# 2   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615982
# 3   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615969
# 4   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615862
#
#    Auftraggeber BestellNr. Kundengrupp  \
# 0          2158       3383  Pharma Pri
# 1     568211765      56141       ANZAG
# 2          2180      91536     PHOENIX
# 3          2155      81548     PHOENIX
# 4          2227      49965     PHOENIX
#
#                                                 Name                Strasse  \
# 0                        Richard Kehr GmbH & Co. KG         Sudetenstraﬂe 8
# 1  Alliance Healthcare Deutschland GmbH Niederlas...      Plauener Str. 161
# 2  PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...    Am Kindleber Feld 3
# 3  PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...     Lengeder Straﬂe 42
# 4  PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...  Schurwaldstraﬂe 14-16
#
#      PLZ           Ort  Artikel      PZN                   Bezeichnung  \
# 0  38114  Braunschweig  7338535  7338535       NOBITE Hautspray 100 ml
# 1  13053        Berlin   325707   325707  NOBITE Kleidung Spray 100 ml
# 2  99867         Gotha  7338535  7338535       NOBITE Hautspray 100 ml
# 3  13407        Berlin   325707   325707  NOBITE Kleidung Spray 100 ml
# 4  73765     Neuhausen   325707   325707  NOBITE Kleidung Spray 100 ml
#
#    Liefermenge  Umsatz        Empfangszeit  Sendung
# 0           36  299.52 2025-12-30 12:30:28  9614926
# 1           24  199.68 2026-01-02 10:26:34  9616810
# 2           12   99.84 2026-01-02 12:02:30  9617516
# 3           12   99.84 2026-01-02 12:01:52  9617495
# 4           12   99.84 2026-01-02 10:12:14  9616702

# %%
df_sales.shape
# Out:
# (436, 19)

# %%
type(df_sales)
# Out:
# pandas.DataFrame

# %%
df_sales.columns
# Out:
# Index(['Versanddatum', 'Auftragsart', 'Qualifier', 'Beschreibung', 'Auftrag',
#        'Auftraggeber', 'BestellNr.', 'Kundengrupp', 'Name', 'Strasse', 'PLZ',
#        'Ort', 'Artikel', 'PZN', 'Bezeichnung', 'Liefermenge', 'Umsatz',
#        'Empfangszeit', 'Sendung'],
#       dtype='str')

# %%
df_sales.dtypes
# Out:
# Versanddatum    datetime64[us]
# Auftragsart                str
# Qualifier                  str
# Beschreibung               str
# Auftrag                  int64
# Auftraggeber             int64
# BestellNr.              object
# Kundengrupp                str
# Name                       str
# Strasse                    str
# PLZ                      int64
# Ort                        str
# Artikel                  int64
# PZN                      int64
# Bezeichnung                str
# Liefermenge              int64
# Umsatz                 float64
# Empfangszeit    datetime64[us]
# Sendung                  int64
# dtype: object

# %%
df_sales.isna().sum()
# Out:
# Versanddatum    0
# Auftragsart     0
# Qualifier       0
# Beschreibung    0
# Auftrag         0
# Auftraggeber    0
# BestellNr.      0
# Kundengrupp     0
# Name            0
# Strasse         0
# PLZ             0
# Ort             0
# Artikel         0
# PZN             0
# Bezeichnung     0
# Liefermenge     0
# Umsatz          0
# Empfangszeit    0
# Sendung         0
# dtype: int64

# %%
df_sales[['Auftragsart', 'Qualifier', 'Beschreibung']].drop_duplicates()
# Out:
#      Auftragsart         Qualifier Beschreibung
# 0  Normalauftrag  Auftragsposition      Verkauf

# %%
df_sales[['Artikel', 'PZN', 'Bezeichnung']].drop_duplicates()
# Out:
#       Artikel       PZN                                Bezeichnung
# 0     7338535   7338535                    NOBITE Hautspray 100 ml
# 1      325707    325707               NOBITE Kleidung Spray 100 ml
# 5     4436102   4436102        NOBITE Kleidung Spr¸hflasche 200 ml
# 22    7392210   7392210  NOBITE Haut Sensitive Spr¸hflasche 100 ml
# 38    4259189   4259189             NOBITE Verd¸nner Flasche 100ml
# 191  18020055  18020055                          NOBITE Kids 100ml

# %%
(df_sales['Artikel'] == df_sales['PZN']).all()
# Out:
# np.True_

# %%
df_sales['PLZ'].astype(str).str.len().value_counts()
# Out:
# PLZ
# 5    389
# 4     47
# Name: count, dtype: int64

# %%
df_sales[df_sales['PLZ'].astype(str).str.len() == 4]['PLZ'].unique()[:10]
# Out:
# array([6193, 4349, 3042, 9116, 4425, 1109, 8393, 9661])

# %%
#looking if text and numbers are mixed 
df_sales['BestellNr.'].apply(type).value_counts()
# Out:
# BestellNr.
# <class 'int'>    357
# <class 'str'>     79
# Name: count, dtype: int64

# %%
#if bestellnr is unique
df_sales['BestellNr.'].nunique()
# Out:
# 269

# %%
df_sales[df_sales['BestellNr.'].duplicated(keep=False)].head(10)
# Out:
#    Versanddatum    Auftragsart         Qualifier Beschreibung  Auftrag  \
# 6    2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615972
# 8    2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615972
# 9    2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615985
# 11   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615802
# 14   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615802
# 19   2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615985
# 21   2026-01-06  Normalauftrag  Auftragsposition      Verkauf   616255
# 23   2026-01-06  Normalauftrag  Auftragsposition      Verkauf   616253
# 24   2026-01-06  Normalauftrag  Auftragsposition      Verkauf   616257
# 26   2026-01-06  Normalauftrag  Auftragsposition      Verkauf   616257
#
#     Auftraggeber       BestellNr. Kundengrupp  \
# 6           2205            73410     PHOENIX
# 8           2205            73410     PHOENIX
# 9          20073          1498095    Sanacorp
# 11          2193  H14169               Noweda
# 14          2193  H14169               Noweda
# 19         20073          1498095    Sanacorp
# 21          2187         82617240    Sanacorp
# 23          2190         62599203    Sanacorp
# 24          2178        122555062    Sanacorp
# 26          2178        122555062    Sanacorp
#
#                                                  Name  \
# 6   PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...
# 8   PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...
# 9                       Leopold Fiebig GmbH & Co. KG
# 11  NOWEDA Arzneimittel AG  Niederlassung Bielefel...
# 14  NOWEDA Arzneimittel AG  Niederlassung Bielefel...
# 19                      Leopold Fiebig GmbH & Co. KG
# 21   Sanacorp Pharmahandel GmbH Niederlassung Hamburg
# 23  Sanacorp Pharmahandel GmbH Niederlassung Lange...
# 24     Sanacorp Pharmahandel GmbH Niederlassung F¸rth
# 26     Sanacorp Pharmahandel GmbH Niederlassung F¸rth
#
#                     Strasse    PLZ           Ort  Artikel      PZN  \
# 6          Kirschbaumweg 23  50996          Kˆln   325707   325707
# 8          Kirschbaumweg 23  50996          Kˆln  7338535  7338535
# 9               Messering 1  76287  Rheinstetten  4436102  4436102
# 11         Einsteinstraﬂe 2  32052       Herford  7338535  7338535
# 14         Einsteinstraﬂe 2  32052       Herford   325707   325707
# 19              Messering 1  76287  Rheinstetten  7338535  7338535
# 21         Marlowring 23-25  22525       Hamburg  7338535  7338535
# 23  In den Kolkwiesen 74-78  30851   Langenhagen  7338535  7338535
# 24       Am Weidiggraben 14  90763         F¸rth  7338535  7338535
# 26       Am Weidiggraben 14  90763         F¸rth  4436102  4436102
#
#                             Bezeichnung  Liefermenge  Umsatz  \
# 6          NOBITE Kleidung Spray 100 ml           48  399.36
# 8               NOBITE Hautspray 100 ml          108  898.56
# 9   NOBITE Kleidung Spr¸hflasche 200 ml            6   63.30
# 11              NOBITE Hautspray 100 ml           12   99.84
# 14         NOBITE Kleidung Spray 100 ml           12   99.84
# 19              NOBITE Hautspray 100 ml           36  299.52
# 21              NOBITE Hautspray 100 ml           36  299.52
# 23              NOBITE Hautspray 100 ml           96  798.72
# 24              NOBITE Hautspray 100 ml           48  399.36
# 26  NOBITE Kleidung Spr¸hflasche 200 ml           12  126.60
#
#           Empfangszeit  Sendung
# 6  2026-01-02 12:01:57  9617497
# 8  2026-01-02 12:01:57  9617497
# 9  2026-01-02 12:10:04  9617564
# 11 2026-01-02 09:34:35  9616413
# 14 2026-01-02 09:34:35  9616413
# 19 2026-01-02 12:10:04  9617564
# 21 2026-01-05 13:33:52  9622138
# 23 2026-01-05 13:33:52  9622132
# 24 2026-01-05 13:33:52  9622144
# 26 2026-01-05 13:33:52  9622144

# %%
df_sales['Kundengrupp'].value_counts()
# Out:
# Kundengrupp
# ANZAG         127
# PHOENIX       105
# Sanacorp       86
# Noweda         69
# TC Privat      26
# Pharma Pri     21
# AEP             2
# Name: count, dtype: int64

# %%
df_sales[['Liefermenge', 'Umsatz']].describe()
# Out:
#        Liefermenge       Umsatz
# count   436.000000   436.000000
# mean     51.740826   458.655321
# std      82.938001   736.123782
# min       6.000000    49.920000
# 25%      12.000000    99.840000
# 50%      24.000000   199.680000
# 75%      60.000000   499.200000
# max     924.000000  7687.680000

# %%
df_sales[['Liefermenge', 'Umsatz']].sum()
# Out:
# Liefermenge     22559.00
# Umsatz         199973.72
# dtype: float64

# %%
df_sales['Versanddatum'].min(), df_sales['Versanddatum'].max()
# Out:
# (Timestamp('2026-01-02 00:00:00'), Timestamp('2026-01-30 00:00:00'))

# %%
#exploring lagerliste jan 2026:
df_inventory = pd.read_excel("data/raw/inventory_2026/LagerlisteTropical-2026-01-31.xlsx")

# %%
df_inventory.head()
# Out:
#    PZN  ArtikelNr                     Bezeichnung    WEDatum    Charge  \
# 0  NaN     325707    NOBITE Kleidung Spray 100 ml 2021-06-22  21013233
# 1  NaN     325707    NOBITE Kleidung Spray 100 ml 2023-03-10  22017398
# 2  NaN     325707    NOBITE Kleidung Spray 100 ml 2024-07-18  24020137
# 3  NaN     325707    NOBITE Kleidung Spray 100 ml 2025-02-19  25020897
# 4  NaN    4259189  NOBITE Verd¸nner Flasche 100ml 2023-08-04  22017249
#
#   Verfalldatum  Status  Anfangsbestand  Zugang  Abgang  ...  \
# 0   2025-09-30       4               2     NaN     NaN  ...
# 1   2025-10-31       4              14     NaN     NaN  ...
# 2   2029-06-30       4               1     NaN     NaN  ...
# 3   2028-01-31       2            3258  3360.0 -2647.0  ...
# 4   2027-08-31       4               3     NaN     NaN  ...
#
#    sonstige Vernichtung  Inventuren  Vernichtung R¸-Mu  Bruch SK  \
# 0                   NaN         NaN                NaN       NaN
# 1                   NaN         NaN                NaN       NaN
# 2                   NaN         NaN                NaN       NaN
# 3                   NaN         NaN                NaN       NaN
# 4                   NaN         NaN                NaN       NaN
#
#    Vernichtung Retouren  Verdeckter Bruch WE  R¸-Mu  Verdeckter Bruch  \
# 0                   NaN                  NaN    NaN               NaN
# 1                   NaN                  NaN    NaN               NaN
# 2                   NaN                  NaN    NaN               NaN
# 3                   NaN                  NaN    NaN               NaN
# 4                   NaN                  NaN    NaN               NaN
#
#    Sonstige  Endbestand
# 0       NaN           2
# 1       NaN          14
# 2       NaN           1
# 3       NaN        3971
# 4       NaN           3
#
# [5 rows x 22 columns]

# %%
df_inventory.shape
# Out:
# (25, 22)

# %%
df_inventory.columns
# Out:
# Index(['PZN', 'ArtikelNr', 'Bezeichnung', 'WEDatum', 'Charge', 'Verfalldatum',
#        'Status', 'Anfangsbestand', 'Zugang', 'Abgang', 'Retouren',
#        'Abgang an Konfektionierung', 'sonstige Vernichtung', 'Inventuren',
#        'Vernichtung R¸-Mu', 'Bruch SK', 'Vernichtung Retouren',
#        'Verdeckter Bruch WE', 'R¸-Mu', 'Verdeckter Bruch', 'Sonstige',
#        'Endbestand'],
#       dtype='str')

# %%
df_inventory.dtypes
# Out:
# PZN                                  float64
# ArtikelNr                              int64
# Bezeichnung                              str
# WEDatum                       datetime64[us]
# Charge                                object
# Verfalldatum                  datetime64[us]
# Status                                 int64
# Anfangsbestand                         int64
# Zugang                               float64
# Abgang                               float64
# Retouren                             float64
# Abgang an Konfektionierung           float64
# sonstige Vernichtung                 float64
# Inventuren                           float64
# Vernichtung R¸-Mu                    float64
# Bruch SK                             float64
# Vernichtung Retouren                 float64
# Verdeckter Bruch WE                  float64
# R¸-Mu                                float64
# Verdeckter Bruch                     float64
# Sonstige                             float64
# Endbestand                             int64
# dtype: object

# %%
df_inventory.isna().sum()
# Out:
# PZN                           25
# ArtikelNr                      0
# Bezeichnung                    0
# WEDatum                        0
# Charge                         0
# Verfalldatum                   0
# Status                         0
# Anfangsbestand                 0
# Zugang                        21
# Abgang                        17
# Retouren                      24
# Abgang an Konfektionierung    25
# sonstige Vernichtung          24
# Inventuren                    25
# Vernichtung R¸-Mu             25
# Bruch SK                      25
# Vernichtung Retouren          25
# Verdeckter Bruch WE           25
# R¸-Mu                         25
# Verdeckter Bruch              25
# Sonstige                      25
# Endbestand                     0
# dtype: int64

# %%
df_inventory[['ArtikelNr', 'Bezeichnung', 'Charge']].drop_duplicates()
# Out:
#     ArtikelNr                                Bezeichnung    Charge
# 0      325707               NOBITE Kleidung Spray 100 ml  21013233
# 1      325707               NOBITE Kleidung Spray 100 ml  22017398
# 2      325707               NOBITE Kleidung Spray 100 ml  24020137
# 3      325707               NOBITE Kleidung Spray 100 ml  25020897
# 4     4259189             NOBITE Verd¸nner Flasche 100ml  22017249
# 5     4259189             NOBITE Verd¸nner Flasche 100ml  23018705
# 6     4436102        NOBITE Kleidung Spr¸hflasche 200 ml  22017077
# 7     4436102        NOBITE Kleidung Spr¸hflasche 200 ml  23018829
# 9     4436102        NOBITE Kleidung Spr¸hflasche 200 ml  23018830
# 10    4436102        NOBITE Kleidung Spr¸hflasche 200 ml  24020633
# 11    4436102        NOBITE Kleidung Spr¸hflasche 200 ml  25021475
# 12    7338535                    NOBITE Hautspray 100 ml     14998
# 13    7338535                    NOBITE Hautspray 100 ml     17545
# 14    7338535                    NOBITE Hautspray 100 ml     17843
# 15    7338535                    NOBITE Hautspray 100 ml     17844
# 16    7338535                    NOBITE Hautspray 100 ml     19892
# 17    7338535                    NOBITE Hautspray 100 ml     20650
# 18    7338535                    NOBITE Hautspray 100 ml     20651
# 21    7338535                    NOBITE Hautspray 100 ml  020652/B
# 22    7392210  NOBITE Haut Sensitive Spr¸hflasche 100 ml  25021015
# 23   18020055                          NOBITE Kids 100ml    424126
# 24   18020055                          NOBITE Kids 100ml    102541

# %%
#Die Produkt-IDs in Sales (Artikel) und Inventory (ArtikelNr) stimmen für Januar 2026 vollständig überein
set(df_sales['Artikel'].unique()) == set(df_inventory['ArtikelNr'].unique())
# Out:
# True

# %%
#Abgang vs. Liefermenge = gleich 
df_inventory['Abgang'].sum(), df_sales['Liefermenge'].sum()
# Out:
# (np.float64(-22559.0), np.int64(22559))

# %%
#Abgang vs. Liefermenge pro product = gleich 
sales_by_product = df_sales.groupby('Artikel')['Liefermenge'].sum()
inventory_by_product = df_inventory.groupby('ArtikelNr')['Abgang'].sum().abs()

sales_by_product, inventory_by_product
# Out:
# (Artikel
#  325707       2647
#  4259189       804
#  4436102      4704
#  7338535     11572
#  7392210      2316
#  18020055      516
#  Name: Liefermenge, dtype: int64,
#  ArtikelNr
#  325707       2647.0
#  4259189       804.0
#  4436102      4704.0
#  7338535     11572.0
#  7392210      2316.0
#  18020055      516.0
#  Name: Abgang, dtype: float64)

# %%
df_inventory.groupby('ArtikelNr')['Endbestand'].sum()
# Out:
# ArtikelNr
# 325707       3988
# 4259189       742
# 4436102      8548
# 7338535     12057
# 7392210      2418
# 18020055     1669
# Name: Endbestand, dtype: int64

# %%
#um statuscodes zu kennen -> wissen nicht was es bedeutet 
df_inventory['Status'].value_counts()
# Out:
# Status
# 4     11
# 2      9
# 1      4
# 70     1
# Name: count, dtype: int64

# %%
#Postleitzahl:
df_plz = pd.read_excel("data/reference/Liste-der-PLZ-in-Excel-Karte-Deutschland-Postleitzahlen.xlsx")

# %%
df_plz.head()
# Out:
#     PLZ Bundesland    Kreis    Typ
# 0  1067    Sachsen  Dresden  Stadt
# 1  1069    Sachsen  Dresden  Stadt
# 2  1097    Sachsen  Dresden  Stadt
# 3  1099    Sachsen  Dresden  Stadt
# 4  1108    Sachsen  Dresden  Stadt

# %%
df_plz.shape
# Out:
# (8196, 4)

# %%
df_plz.columns
# Out:
# Index(['PLZ', 'Bundesland', 'Kreis', 'Typ'], dtype='str')

# %%
df_plz.dtypes
# Out:
# PLZ           int64
# Bundesland      str
# Kreis           str
# Typ             str
# dtype: object

# %%
df_plz.isna().sum()
# Out:
# PLZ           0
# Bundesland    0
# Kreis         0
# Typ           0
# dtype: int64

# %%
df_sales['PLZ'].isin(df_plz['PLZ']).value_counts()
# Out:
# PLZ
# True    436
# Name: count, dtype: int64

# %%
#Cleaning sales: 
#SALES
#1. PLZ → String + 5 Stellen
#2. BestellNr. → String
#3. Artikel → String
#4. PZN → String
#5. Dates checken

# %%
sales_clean = df_sales.copy()

# %%
#plz clean:
sales_clean['PLZ'] = sales_clean['PLZ'].astype(str).str.zfill(5)
sales_clean['PLZ'].head()
# Out:
# 0    38114
# 1    13053
# 2    99867
# 3    13407
# 4    73765
# Name: PLZ, dtype: str

# %%
sales_clean['PLZ'].str.len().value_counts()
# Out:
# PLZ
# 5    436
# Name: count, dtype: int64

# %%
#BestellNr. zu Text machen
sales_clean['BestellNr.'] = sales_clean['BestellNr.'].astype(str)
sales_clean['BestellNr.'].apply(type).value_counts()
# Out:
# BestellNr.
# <class 'str'>    436
# Name: count, dtype: int64

# %%
#artike und PZN zu Text
sales_clean['Artikel'] = sales_clean['Artikel'].astype(str)
sales_clean['PZN'] = sales_clean['PZN'].astype(str)

# %%
sales_clean[['Artikel', 'PZN']].dtypes
# Out:
# Artikel    str
# PZN        str
# dtype: object

# %%
sales_clean[['Versanddatum', 'Empfangszeit']].dtypes
# Out:
# Versanddatum    datetime64[us]
# Empfangszeit    datetime64[us]
# dtype: object

# %%
################################cleaning inventory#######################################

# %%
inventory_clean = df_inventory.copy()

# %%
inventory_clean['ArtikelNr'] = inventory_clean['ArtikelNr'].astype(str)

# %%
inventory_clean['Charge'] = inventory_clean['Charge'].astype(str)

# %%
inventory_clean[['Zugang', 'Abgang', 'Retouren', 'sonstige Vernichtung', 'Inventuren']] = (
    inventory_clean[['Zugang', 'Abgang', 'Retouren', 'sonstige Vernichtung', 'Inventuren']].fillna(0)
)

# %%
df_plz['PLZ'] = df_plz['PLZ'].astype(str).str.zfill(5)

# %%
#kopie von plz tabelle:
plz_clean = df_plz.copy()

# %%
plz_clean['PLZ'] = plz_clean['PLZ'].astype(str).str.zfill(5)

# %%
plz_clean['PLZ'].str.len().value_counts()
# Out:
# PLZ
# 5    8196
# Name: count, dtype: int64

# %%
#######################merge#######################################
#umsatzstatistik mit PLZ

# %%
sales_clean = sales_clean.merge(plz_clean, on='PLZ', how='left')

# %%
sales_clean[['PLZ', 'Bundesland', 'Kreis', 'Typ']].head()
# Out:
#      PLZ         Bundesland         Kreis    Typ
# 0  38114      Niedersachsen  Braunschweig  Stadt
# 1  13053             Berlin        Berlin  Stadt
# 2  99867          Thüringen         Gotha  Kreis
# 3  13407             Berlin        Berlin  Stadt
# 4  73765  Baden-Württemberg     Esslingen  Kreis

# %%
sales_clean.shape
# Out:
# (436, 22)

# %%
##cleaning function sales & plz

# %%
def clean_sales(df, plz_df):
    df = df.copy()

    df['PLZ'] = df['PLZ'].astype(str).str.zfill(5)
    df['BestellNr.'] = df['BestellNr.'].astype(str)
    df['Artikel'] = df['Artikel'].astype(str)
    df['PZN'] = df['PZN'].astype(str)

    df['Ort'] = df['Ort'].apply(clean_text)
    df['Bezeichnung'] = df['Bezeichnung'].apply(clean_text)

    df['Berichtsmonat'] = df['Versanddatum'].dt.to_period('M').astype(str)

    df = df.merge(plz_df, on='PLZ', how='left')

    return df

# %%
sales_test = clean_sales(df_sales, plz_clean)

# %%
sales_test.shape
# Out:
# (436, 23)

# %%
clean_sales(df_sales, plz_clean)
# Out:
#     Versanddatum    Auftragsart         Qualifier Beschreibung  Auftrag  \
# 0     2026-01-02  Normalauftrag  Auftragsposition      Verkauf   615752
# 1     2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615885
# 2     2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615982
# 3     2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615969
# 4     2026-01-05  Normalauftrag  Auftragsposition      Verkauf   615862
# ..           ...            ...               ...          ...      ...
# 431   2026-01-30  Normalauftrag  Auftragsposition      Verkauf   620050
# 432   2026-01-30  Normalauftrag  Auftragsposition      Verkauf   619954
# 433   2026-01-30  Normalauftrag  Auftragsposition      Verkauf   619955
# 434   2026-01-30  Normalauftrag  Auftragsposition      Verkauf   619956
# 435   2026-01-30  Normalauftrag  Auftragsposition      Verkauf   619925
#
#      Auftraggeber       BestellNr. Kundengrupp  \
# 0            2158             3383  Pharma Pri
# 1       568211765            56141       ANZAG
# 2            2180            91536     PHOENIX
# 3            2155            81548     PHOENIX
# 4            2227            49965     PHOENIX
# ..            ...              ...         ...
# 431          2192  I51496               Noweda
# 432          2226  N35000               Noweda
# 433          2241  R61269               Noweda
# 434          2299  T55695               Noweda
# 435          2208           506072  Pharma Pri
#
#                                                   Name                Strasse  \
# 0                          Richard Kehr GmbH & Co. KG         Sudetenstraﬂe 8
# 1    Alliance Healthcare Deutschland GmbH Niederlas...      Plauener Str. 161
# 2    PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...    Am Kindleber Feld 3
# 3    PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...     Lengeder Straﬂe 42
# 4    PHOENIX Pharmahandel GmbH & Co. KG Vertriebsze...  Schurwaldstraﬂe 14-16
# ..                                                 ...                    ...
# 431  Ebert & Jacobi GmbH & Co. KG Zweigniederlassun...  Nattheimer Straﬂe 106
# 432  NOWEDA Pharma-Handels-GmbH  Auslieferungsdepot...   Am Hochheimer See 11
# 433                              NOWEDA GmbH & Co. KG       Apothekerstraﬂe 1
# 434                        NOWEDA Pharma-Handels-GmbH       Apothekerstraﬂe 1
# 435  Max Jenne Arzneimittel-Groﬂhandlung KG Zweigni...        Novgorodstr. 12
#
#      ...      PZN                          Bezeichnung Liefermenge  Umsatz  \
# 0    ...  7338535              NOBITE Hautspray 100 ml          36  299.52
# 1    ...   325707         NOBITE Kleidung Spray 100 ml          24  199.68
# 2    ...  7338535              NOBITE Hautspray 100 ml          12   99.84
# 3    ...   325707         NOBITE Kleidung Spray 100 ml          12   99.84
# 4    ...   325707         NOBITE Kleidung Spray 100 ml          12   99.84
# ..   ...      ...                                  ...         ...     ...
# 431  ...  7338535              NOBITE Hautspray 100 ml          12   99.84
# 432  ...  7338535              NOBITE Hautspray 100 ml          12   99.84
# 433  ...  4436102  NOBITE Kleidung Sprühflasche 200 ml          12  126.60
# 434  ...  4259189       NOBITE Verdünner Flasche 100ml          36  379.80
# 435  ...  4436102  NOBITE Kleidung Sprühflasche 200 ml           6   63.30
#
#            Empfangszeit  Sendung  Berichtsmonat          Bundesland  \
# 0   2025-12-30 12:30:28  9614926        2026-01       Niedersachsen
# 1   2026-01-02 10:26:34  9616810        2026-01              Berlin
# 2   2026-01-02 12:02:30  9617516        2026-01           Thüringen
# 3   2026-01-02 12:01:52  9617495        2026-01              Berlin
# 4   2026-01-02 10:12:14  9616702        2026-01   Baden-Württemberg
# ..                  ...      ...            ...                 ...
# 431 2026-01-29 12:30:11  9727418        2026-01   Baden-Württemberg
# 432 2026-01-29 09:40:07  9725245        2026-01           Thüringen
# 433 2026-01-29 09:40:07  9725249        2026-01             Sachsen
# 434 2026-01-29 09:40:07  9725253        2026-01             Sachsen
# 435 2026-01-29 09:30:20  9725123        2026-01  Schleswig-Holstein
#
#              Kreis    Typ
# 0     Braunschweig  Stadt
# 1           Berlin  Stadt
# 2            Gotha  Kreis
# 3           Berlin  Stadt
# 4        Esslingen  Kreis
# ..             ...    ...
# 431     Heidenheim  Kreis
# 432          Gotha  Kreis
# 433  Mittelsachsen  Kreis
# 434    Nordsachsen  Kreis
# 435         Lübeck  Stadt
#
# [436 rows x 23 columns]

# %%
##cleaning function inevntory

# %%
def clean_inventory(df):
    df = df.copy()

    df['ArtikelNr'] = df['ArtikelNr'].astype(str)
    df['Charge'] = df['Charge'].astype(str)
    df['Bezeichnung'] = df['Bezeichnung'].apply(clean_text)

    df[['Zugang', 'Abgang', 'Retouren', 'sonstige Vernichtung', 'Inventuren']] = (
        df[['Zugang', 'Abgang', 'Retouren', 'sonstige Vernichtung', 'Inventuren']].fillna(0)
    )

    return df

# %%
inventory_test = clean_inventory(df_inventory)

# %%
inventory_test.shape
# Out:
# (25, 22)

# %%
#testing jan, feb, march 2026: sales

# %%
df_sales_jan = pd.read_excel("data/raw/sales_2026/Umsatzstatistik Tropical Concept 31.01.2026.xlsx")
df_sales_feb = pd.read_excel("data/raw/sales_2026/Umsatzstatistik Tropical Concept 28.02.2026.xlsx")
df_sales_mar = pd.read_excel("data/raw/sales_2026/Umsatzstatistik Tropical Concept 31.03.2026.xlsx")

sales_jan_clean = clean_sales(df_sales_jan, plz_clean)
sales_feb_clean = clean_sales(df_sales_feb, plz_clean)
sales_mar_clean = clean_sales(df_sales_mar, plz_clean)

sales_all = pd.concat([sales_jan_clean, sales_feb_clean, sales_mar_clean], ignore_index=True)
sales_all.shape
# Out:
# (1453, 23)

# %%
len(sales_jan_clean) + len(sales_feb_clean) + len(sales_mar_clean) == len(sales_all)
# Out:
# True

# %%
sales_all['Bundesland'].isna().sum()
# Out:
# np.int64(0)

# %%
sales_all['Versanddatum'].min(), sales_all['Versanddatum'].max()
# Out:
# (Timestamp('2026-01-02 00:00:00'), Timestamp('2026-03-31 00:00:00'))

# %%
sales_all[['Liefermenge', 'Umsatz']].apply(pd.to_numeric, errors='coerce').isna().sum()
# Out:
# Liefermenge    0
# Umsatz         0
# dtype: int64

# %%
sales_all.duplicated().sum()
# Out:
# np.int64(0)

# %%
##Umlaute anschauen:

# %%
sales_all[sales_all['Ort'].str.contains(r"['¸,]", regex=True, na=False)]['Ort'].unique()
# Out:
# <ArrowStringArray>
# []
# Length: 0, dtype: str

# %%
sales_all[sales_all['Bezeichnung'].str.contains(r"[¸',]", regex=True, na=False)]['Bezeichnung'].unique()
# Out:
# <ArrowStringArray>
# []
# Length: 0, dtype: str

# %%
sales_all[sales_all['Ort'].str.contains(r"[¸ˆ]", regex=True, na=False)]['Ort'].unique()
# Out:
# <ArrowStringArray>
# []
# Length: 0, dtype: str

# %%
def clean_text(text):
    return text.replace('¸', 'ü').replace('ˆ', 'ö')

# %%
sales_all['Ort'] = sales_all['Ort'].apply(clean_text)
sales_all['Bezeichnung'] = sales_all['Bezeichnung'].apply(clean_text)

# %%
sales_all[sales_all['Ort'].str.contains(r"[¸ˆ]", regex=True, na=False)]['Ort'].unique()
# Out:
# <ArrowStringArray>
# []
# Length: 0, dtype: str

# %%
sales_all[sales_all['Bezeichnung'].str.contains(r"[¸ˆ]", regex=True, na=False)]['Bezeichnung'].unique()
# Out:
# <ArrowStringArray>
# []
# Length: 0, dtype: str

# %%
#testing jan, feb, march 2026: inventory

# %%
df_inventory_jan = pd.read_excel("data/raw/inventory_2026/LagerlisteTropical-2026-01-31.xlsx")
df_inventory_feb = pd.read_excel("data/raw/inventory_2026/LagerlisteTropical-2026-02-28.xlsx")
df_inventory_mar = pd.read_excel("data/raw/inventory_2026/LagerlisteTropical-2026-03-31.xlsx")

inventory_jan_clean = clean_inventory(df_inventory_jan)
inventory_feb_clean = clean_inventory(df_inventory_feb)
inventory_mar_clean = clean_inventory(df_inventory_mar)

inventory_jan_clean['Berichtsmonat'] = '2026-01'
inventory_feb_clean['Berichtsmonat'] = '2026-02'
inventory_mar_clean['Berichtsmonat'] = '2026-03'

inventory_all = pd.concat([inventory_jan_clean, inventory_feb_clean, inventory_mar_clean], ignore_index=True) 
inventory_all.shape
# Out:
# (77, 23)

# %%
inventory_all.duplicated().sum()
# Out:
# np.int64(0)

# %%
abs(inventory_all['Abgang'].sum()), sales_all['Liefermenge'].sum()
# Out:
# (np.float64(96281.0), np.int64(96281))

# %%
sales_all.groupby('Berichtsmonat')['Liefermenge'].sum()
# Out:
# Berichtsmonat
# 2026-01    22559
# 2026-02    27617
# 2026-03    46105
# Name: Liefermenge, dtype: int64

# %%
inventory_all.groupby('Berichtsmonat')['Abgang'].sum().abs()
# Out:
# Berichtsmonat
# 2026-01    22559.0
# 2026-02    27617.0
# 2026-03    46105.0
# Name: Abgang, dtype: float64
